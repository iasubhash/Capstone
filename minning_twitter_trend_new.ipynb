# %%
#importing all dependencies
import numpy as np
import tweepy
import requests
import base64

#Define your keys from the developer portal

# %%
consumer_key = 'baQFuh3OsgdF9OsFWC7BNHsBL'
consumer_secret_key = 'qHcLnTvXYHp3Ir3xYZgSk0706BKENWcR3yDCZSy5VuU9Y0zDrL'

# %%
#Reformat the keys and encode them
key_secret = '{}:{}'.format(consumer_key, consumer_secret_key).encode('ascii')
#Transform from bytes to bytes that can be printed
b64_encoded_key = base64.b64encode(key_secret)
#Transform from bytes back into Unicode
b64_encoded_key = b64_encoded_key.decode('ascii')

# %%
base_url = 'https://api.twitter.com/'
auth_url = '{}oauth2/token'.format(base_url)
auth_headers = {
    'Authorization': 'Basic {}'.format(b64_encoded_key),
    'Content-Type': 'application/x-www-form-urlencoded;charset=UTF-8'
}
auth_data = {
    'grant_type': 'client_credentials'
}
auth_resp = requests.post(auth_url, headers=auth_headers, data=auth_data)
print(auth_resp.status_code)
access_token = auth_resp.json()['access_token']
# Out:
# 200

# %%
trend_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
}

trend_params = {
    'id': 2295407,
}

#global 1
#US 23424977
#India 2295407
#Mumbai 2295411

trend_url = 'https://api.twitter.com/1.1/trends/place.json'  
trend_resp = requests.get(trend_url, headers=trend_headers, params=trend_params)

# %%
tweet_data = trend_resp.json()
#print(tweet_data)
for i in range(0,20):
  print(tweet_data[0]['trends'][i])
# Out:
# {'name': '#BiharElectionResults', 'url': 'http://twitter.com/search?q=%23BiharElectionResults', 'promoted_content': None, 'query': '%23BiharElectionResults', 'tweet_volume': 135091}
# {'name': '#Dream11IPLFinal', 'url': 'http://twitter.com/search?q=%23Dream11IPLFinal', 'promoted_content': None, 'query': '%23Dream11IPLFinal', 'tweet_volume': None}
# {'name': '#DubbakaElections', 'url': 'http://twitter.com/search?q=%23DubbakaElections', 'promoted_content': None, 'query': '%23DubbakaElections', 'tweet_volume': None}
# {'name': '#FilterByJimin100M', 'url': 'http://twitter.com/search?q=%23FilterByJimin100M', 'promoted_content': None, 'query': '%23FilterByJimin100M', 'tweet_volume': 33486}
# {'name': 'Congress', 'url': 'http://twitter.com/search?q=Congress', 'promoted_content': None, 'query': 'Congress', 'tweet_volume': 230738}
# ...

# %%
hashtags = []
trends = tweet_data[0]['trends']
for trend in trends:
    name = trend['name']
    if name.startswith('#'):
        hashtags.append(name)

# %%
trend_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
}

trend_params = {
    'id': 2295411,
}

#global 1
#US 23424977
#India 2295407
#Mumbai 2295411

trend_url = 'https://api.twitter.com/1.1/trends/place.json'  
trend_resp = requests.get(trend_url, headers=trend_headers, params=trend_params)

# %%
###appending Mumbai trends to hashtags
tweet_data = trend_resp.json()
#print(tweet_data)
for i in range(0,20):
  print(tweet_data[0]['trends'][i])

trends = tweet_data[0]['trends']
for trend in trends:
    name = trend['name']
    if name.startswith('#'):
        hashtags.append(name)
# Out:
# {'name': '#BiharElectionResults', 'url': 'http://twitter.com/search?q=%23BiharElectionResults', 'promoted_content': None, 'query': '%23BiharElectionResults', 'tweet_volume': 135091}
# {'name': 'Congress', 'url': 'http://twitter.com/search?q=Congress', 'promoted_content': None, 'query': 'Congress', 'tweet_volume': 230738}
# {'name': '#MIvDC', 'url': 'http://twitter.com/search?q=%23MIvDC', 'promoted_content': None, 'query': '%23MIvDC', 'tweet_volume': 17337}
# {'name': '#BiharElections2020', 'url': 'http://twitter.com/search?q=%23BiharElections2020', 'promoted_content': None, 'query': '%23BiharElections2020', 'tweet_volume': 22780}
# {'name': '#Dream11IPLFinal', 'url': 'http://twitter.com/search?q=%23Dream11IPLFinal', 'promoted_content': None, 'query': '%23Dream11IPLFinal', 'tweet_volume': None}
# {'name': '#DubbakaBypolls', 'url': 'http://twitter.com/search?q=%23DubbakaBypolls', 'promoted_content': None, 'query': '%23DubbakaBypolls', 'tweet_volume': None}
# ...

# %%
trend_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
}

trend_params = {
    'id': 23424977,
}

#global 1
#US 23424977
#India 2295407
#Mumbai 2295411

trend_url = 'https://api.twitter.com/1.1/trends/place.json'  
trend_resp = requests.get(trend_url, headers=trend_headers, params=trend_params)

# %%
###appending US trends to hashtags

tweet_data = trend_resp.json()
#print(tweet_data)
for i in range(0,20):
  print(tweet_data[0]['trends'][i])

trends = tweet_data[0]['trends']
for trend in trends:
    name = trend['name']
    if name.startswith('#'):
        hashtags.append(name)
# Out:
# {'name': '#tuesdayvibe', 'url': 'http://twitter.com/search?q=%23tuesdayvibe', 'promoted_content': None, 'query': '%23tuesdayvibe', 'tweet_volume': 35305}
# {'name': 'Major League', 'url': 'http://twitter.com/search?q=%22Major+League%22', 'promoted_content': None, 'query': '%22Major+League%22', 'tweet_volume': None}
# {'name': '#Marines', 'url': 'http://twitter.com/search?q=%23Marines', 'promoted_content': None, 'query': '%23Marines', 'tweet_volume': None}
# {'name': '#LoveKilla1stWin', 'url': 'http://twitter.com/search?q=%23LoveKilla1stWin', 'promoted_content': None, 'query': '%23LoveKilla1stWin', 'tweet_volume': 89585}
# {'name': 'Bull Durham', 'url': 'http://twitter.com/search?q=%22Bull+Durham%22', 'promoted_content': None, 'query': '%22Bull+Durham%22', 'tweet_volume': None}
# {'name': 'Field of Dreams', 'url': 'http://twitter.com/search?q=%22Field+of+Dreams%22', 'promoted_content': None, 'query': '%22Field+of+Dreams%22', 'tweet_volume': None}
# ...

# %%
trend_headers = {
    'Authorization': 'Bearer {}'.format(access_token)    
}

trend_params = {
    'id': 1,
}

#global 1
#US 23424977
#India 2295407
#Mumbai 2295411

trend_url = 'https://api.twitter.com/1.1/trends/place.json'  
trend_resp = requests.get(trend_url, headers=trend_headers, params=trend_params)

# %%
###appending Global trends to hashtags

tweet_data = trend_resp.json()
#print(tweet_data)
for i in range(0,20):
  print(tweet_data[0]['trends'][i])

trends = tweet_data[0]['trends']
for trend in trends:
    name = trend['name']
    if name.startswith('#'):
        hashtags.append(name)
# Out:
# {'name': '#LoveKilla1stWin', 'url': 'http://twitter.com/search?q=%23LoveKilla1stWin', 'promoted_content': None, 'query': '%23LoveKilla1stWin', 'tweet_volume': 89585}
# {'name': '#ありがとう藤川球児', 'url': 'http://twitter.com/search?q=%23%E3%81%82%E3%82%8A%E3%81%8C%E3%81%A8%E3%81%86%E8%97%A4%E5%B7%9D%E7%90%83%E5%85%90', 'promoted_content': None, 'query': '%23%E3%81%82%E3%82%8A%E3%81%8C%E3%81%A8%E3%81%86%E8%97%A4%E5%B7%9D%E7%90%83%E5%85%90', 'tweet_volume': 33154}
# {'name': '#BidenWasNotElected', 'url': 'http://twitter.com/search?q=%23BidenWasNotElected', 'promoted_content': None, 'query': '%23BidenWasNotElected', 'tweet_volume': 28928}
# {'name': '#姉ちゃんの恋人', 'url': 'http://twitter.com/search?q=%23%E5%A7%89%E3%81%A1%E3%82%83%E3%82%93%E3%81%AE%E6%81%8B%E4%BA%BA', 'promoted_content': None, 'query': '%23%E5%A7%89%E3%81%A1%E3%82%83%E3%82%93%E3%81%AE%E6%81%8B%E4%BA%BA', 'tweet_volume': 14058}
# ...

# %%
print(hashtags)
# Out:
# ['#BiharElectionResults', '#Dream11IPLFinal', '#DubbakaElections', '#FilterByJimin100M', '#SpeakForUyghurs', '#BiharWinByFadnavis', '#IPL2020final', '#BJPSweepsGujarat', '#DubbakaBypollResults', '#BiharResults', '#Andhaghaaram', '#TuMeraNahi10M', '#BoycottAmazon', '#BiharElections2020', '#தமிழர்வாழ_தினகரன்ஆளட்டும்', '#MouseHunt', '#BiskothDiwali', '#AIMIM', '#raghunandanrao', '#bypolls', '#BJPWinsGujarat', '#IrandamKuththu', '#ReleaseArnabVoiceOfSSR', '#1YearOfITABestJodiAshDeep', '#LoveKilla1stWin', '#BiharElectionResults', '#MIvDC', '#BiharElections2020', '#Dream11IPLFinal', '#DubbakaBypolls', '#BJPSweepsGujarat', '#BoycottAmazon', '#ReleaseArnabVoiceOfSSR', '#NitishKumar', '#tuesdayvibe', '#DubbakaElections', '#FilterByJimin100M', '#SpeakForUyghurs', '#BiharWinByFadnavis', '#IPL2020final', '#DubbakaBypollResults', '#BiharResults', '#Andhaghaaram', '#TuMeraNahi10M', '#தமிழர்வாழ_தினகரன்ஆளட்டும்', '#MouseHunt', '#BiskothDiwali', '#AIMIM', '#raghunandanrao', '#BJPWinsGujarat', '#tuesd
# ...

# %%
df_ht = pd.DataFrame(hashtags)

# %%
df_ht
# Out:
#                         0
# 0   #BiharElectionResults
# 1        #Dream11IPLFinal
# 2       #DubbakaElections
# 3      #FilterByJimin100M
# 4        #SpeakForUyghurs
# ..                    ...
# 71      #StrawberryPrince
# 72            #お前らの通勤車を晒せ
# 73                  #うたコン
# 74            #マツコの知らない世界
# 75  #BiharElectionResults
#
# [76 rows x 1 columns]

# %%
df_ht
# Out:
#                         0
# 0   #BiharElectionResults
# 1        #Dream11IPLFinal
# 2       #DubbakaElections
# 3      #FilterByJimin100M
# 4        #SpeakForUyghurs
# ..                    ...
# 71      #StrawberryPrince
# 72            #お前らの通勤車を晒せ
# 73                  #うたコン
# 74            #マツコの知らない世界
# 75  #BiharElectionResults
#
# [76 rows x 1 columns]

# %%
df_ht = df_ht.rename(columns={0: 'keywords'})

# %%
import string
printable = set(string.printable)
df_ht['keywords'] = df_ht['keywords'].apply(lambda row: ''.join(filter(lambda x: x in printable, row)))
df_ht
# Out:
#                  keywords
# 0   #BiharElectionResults
# 1        #Dream11IPLFinal
# 2       #DubbakaElections
# 3      #FilterByJimin100M
# 4        #SpeakForUyghurs
# ..                    ...
# 71      #StrawberryPrince
# 72                      #
# 73                      #
# 74                      #
# 75  #BiharElectionResults
#
# [76 rows x 1 columns]

# %%
df_ht
# Out:
#                  keywords
# 0   #BiharElectionResults
# 1        #Dream11IPLFinal
# 2       #DubbakaElections
# 3      #FilterByJimin100M
# 4        #SpeakForUyghurs
# ..                    ...
# 71      #StrawberryPrince
# 72                      #
# 73                      #
# 74                      #
# 75  #BiharElectionResults
#
# [76 rows x 1 columns]

# %%
df_ht['keywords'] = df_ht['keywords'].map(lambda x: x.lstrip('#'))

# %%
df_ht
# Out:
#                 keywords
# 0   BiharElectionResults
# 1        Dream11IPLFinal
# 2       DubbakaElections
# 3      FilterByJimin100M
# 4        SpeakForUyghurs
# ..                   ...
# 71      StrawberryPrince
# 72
# 73
# 74
# 75  BiharElectionResults
#
# [76 rows x 1 columns]

# %%
df_ht['keywords']= df_ht['keywords'].str.lower()

# %%
df_ht
# Out:
#                 keywords
# 0   biharelectionresults
# 1        dream11iplfinal
# 2       dubbakaelections
# 3      filterbyjimin100m
# 4        speakforuyghurs
# ..                   ...
# 71      strawberryprince
# 72
# 73
# 74
# 75  biharelectionresults
#
# [76 rows x 1 columns]

# %%
import pandas as pd
from ast import literal_eval

# %%
df_kw = pd.read_csv('C:\\Users\\Subhash\\_GL\\Recom\\\keywords.csv')

# %%
df_kw.head()
# Out:
#       id                                           keywords
# 0    862  [{'id': 931, 'name': 'jealousy'}, {'id': 4290,...
# 1   8844  [{'id': 10090, 'name': 'board game'}, {'id': 1...
# 2  15602  [{'id': 1495, 'name': 'fishing'}, {'id': 12392...
# 3  31357  [{'id': 818, 'name': 'based on novel'}, {'id':...
# 4  11862  [{'id': 1009, 'name': 'baby'}, {'id': 1599, 'n...

# %%
df_kw['keywords'] = df_kw['keywords'] .fillna('[]').apply(literal_eval).apply(lambda x: [i['name'] for i in x] if isinstance(x, list) else [])

# %%
df_kw.keywords
# Out:
# 0        [jealousy, toy, boy, friendship, friends, riva...
# 1        [board game, disappearance, based on children'...
# 2        [fishing, best friend, duringcreditsstinger, o...
# 3        [based on novel, interracial relationship, sin...
# 4        [baby, midlife crisis, confidence, aging, daug...
#                                ...
# 46414                                        [tragic love]
# 46415                                [artist, play, pinoy]
# 46416                                                   []
# 46417                                                   []
# 46418                                                   []
# Name: keywords, Length: 46419, dtype: object

# %%
s = df_kw.apply(lambda x: pd.Series(x['keywords']),axis=1).stack().reset_index(level=1, drop=True)
s.name = 'keywords'

# %%
df_kw = df_kw.drop('keywords', axis=1).join(s)

# %%
df_kw
# Out:
#            id    keywords
# 0         862    jealousy
# 0         862         toy
# 0         862         boy
# 0         862  friendship
# 0         862     friends
# ...       ...         ...
# 46415  111109        play
# 46415  111109       pinoy
# 46416   67758         NaN
# 46417  227506         NaN
# 46418  461257         NaN
#
# [173475 rows x 2 columns]

# %%
df_mix = pd.merge(df_kw, df_ht, on="keywords", how='outer', indicator='Exist')
df_mix  = df_mix.loc[df_mix['Exist'] == 'both']

# %%
df_mix
# Out:
#               id  keywords Exist
# 125264      75.0  congress  both
# 125265   24481.0  congress  both
# 125266   14902.0  congress  both
# 125267   10618.0  congress  both
# 125268    7512.0  congress  both
# 125269    6538.0  congress  both
# 125270   16995.0  congress  both
# 125271   51447.0  congress  both
# 125272  100420.0  congress  both

# %%
# End of my code -Subhash
